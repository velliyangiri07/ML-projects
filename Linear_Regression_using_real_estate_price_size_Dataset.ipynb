# %% [markdown]
# <a href="https://colab.research.google.com/github/velliyangiri07/ML-projects/blob/main/Linear_Regression_using_real_estate_price_size_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/real_estate_price_size.csv')
df
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# price    0
# size     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(df['price'],df['size'])
plt.show()

# %%
x=df.drop('price',axis=1)
y=df['price']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [216.2530156]
# 104769.58663142886

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6921167959760717

# %%
lr.predict([[1900]])
# Out:
# array([515650.31626523])

# %%
plt.scatter(x_train,y_train,color='b')
plt.plot(x_test,y_pred,color='r')
plt.show()
