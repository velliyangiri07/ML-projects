# %% [markdown]
# <a href="https://colab.research.google.com/github/velliyangiri07/ML-projects/blob/main/Diabetes_detection_using_DecisionTreeClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # separate the features and the target variable

# %%
x=df.drop('Outcome',axis=1)
y=df['Outcome']
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# # splits the dataset into training and testing sets
# 1.  test_size=0.2
#   * 20% of the data will be used for testing
#   * 80% will be used for training
# 2.  random_state=0
#   * get the same split every time

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# # imports the DecisionTreeClassifier from scikit-learn

# %%
from  sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

# %% [markdown]
# # Train the model using Training data

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Make predictions on the test input data

# %%
y_pred = clf.predict(x_test)

# %% [markdown]
# # calculates the accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7727272727272727

# %% [markdown]
# # visualize your trained Decision Tree model
#
#
# *   feature_names=x.columns: shows the actual column names instead of generic feature names like X[0], X[1], etc.
#
# *   filled=True: colors the nodes based on class outcome (makes it easy to understand)

# %%
from sklearn.tree import export_graphviz
import graphviz
graphviz.Source(export_graphviz(clf,feature_names=x.columns,filled = True))
